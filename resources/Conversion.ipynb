# %%
import pandas as pd

# %%
weather_df = pd.read_csv('weather_data.csv')

# %%
weather_df
# Out:
#             City Country  Latitude  Longintude  Temperature (F)  % Humidity  \
# 0       Pochutla      MX     15.74      -96.47            84.99          73
# 1          Vaini      TO    -21.20     -175.20            77.00          73
# 2         Hasaki      JP     35.73      140.83            86.77          74
# 3         Narsaq      GL     60.92      -46.05            46.40          87
# 4       Hermanus      ZA    -34.42       19.23            55.00          88
# ..           ...     ...       ...         ...              ...         ...
# 551      Mareeba      AU    -17.00      145.43            76.23          65
# 552   Veselynove      UA     47.36       31.23            63.77          53
# 553  Belaya Gora      RU     68.53      146.42            57.33          51
# 554      Tuy Hoa      VN     13.08      109.30            86.11          67
# 555        Aketi      CD      2.74       23.78            70.68          97
#
#      % Cloud Cover  Wind Speed (MPH)
# ...

# %%
weather_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longintude</th>\n      <th>Temperature (F)</th>\n      <th>% Humidity</th>\n      <th>% Cloud Cover</th>\n      <th>Wind Speed (MPH)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Pochutla</td>\n      <td>MX</td>\n      <td>15.74</td>\n      <td>-96.47</td>\n      <td>84.99</td>\n      <td>73</td>\n      <td>24</td>\n      <td>3.44</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Vaini</td>\n      <td>TO</td>\n      <td>-21.20</td>\n      <td>-175.20</td>\n      <td>77.00</td>\n      <td>73</td>\n      <td>75</td>\n      <td>11.41</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Hasaki</td>\n      <td>JP</td>\n      <td>35.73</td>\n      <td>140.83</td>\n      <td>86.77</td>\n      <td>74</td>\n      <td>40</td>\n      <td>4.70</td>\n    </tr>\n    <tr>\n      
# ...
